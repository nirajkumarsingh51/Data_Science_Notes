# %%
import pandas as pd

#data = pd.Series([1, 2, 3, 4, 5])
data = pd.Series([80, 90, 75, 85, 95], 
index=['Niraj', 'Suman', 'Rohit', 'Sita', 'Gita'])
print(data['Niraj'])  # Accessing element by index
# Out:
# 80

# %%
data = pd.Series( ['Niraj', 'Suman', 'Rohit', 'Sita', 'Gita'] , index= [80, 90, 75, 85, 95])
print(data[80])
# Out:
# Niraj

# %%
marks = pd.Series([80, 90, 75, 85, 95])
print(marks + 5)
print(marks * 2)
# Out:
# 0     85
# 1     95
# 2     80
# 3     90
# 4    100
# dtype: int64
# 0    160
# 1    180
# 2    150
# 3    170
# 4    190
# dtype: int64
