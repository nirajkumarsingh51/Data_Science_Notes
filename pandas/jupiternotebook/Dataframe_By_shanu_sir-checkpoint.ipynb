# %%
import pandas as pd

# %%
import pandas as pd
student = {
    "Name": ["Rahul", "Aman", "Priya","Supriya"],
    "Age": [20, 21, 19,22],
    "Marks": [85, 90, 88,70]
}

print(df)
# Out:
#     Name  Age  Marks
# 0  Rahul   20     85
# 1   Aman   21     90
# 2  Priya   19     88

# %%
df = pd.DataFrame(student)
# print(df)
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='str')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)
